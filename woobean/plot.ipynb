# %%
import matplotlib.pyplot as plt
import scipy.io as sio 
import os
import scipy.signal as signal
import numpy as np


path = '../ECoG_Handpose.mat'
data_set = sio.loadmat(path)['y']
data_set.shape
# Out:
# (67, 507025)

# %%
RELAX = 0 
FIST_MOVEMENT = 1
PEACE_MOVEMENT =2  
OPEN_HAND = 3

# %%
# Bar chart of Paradigm Info
paradigm_info = data_set[61]
unique, counts = np.unique(paradigm_info, return_counts=True)
plt.bar(unique, counts)
# Out:
# <BarContainer object of 4 artists>

# %%
unique, counts
# Out:
# (array([0., 1., 2., 3.]), array([286801,  73440,  73440,  73344]))

# %%
# Change in Paradigm Info over time
plt.figure(figsize=(22,4 ))
plt.plot(data_set[0], data_set[61])
plt.show()

# %%
## Delete initial signal until open hand starts -> data_set[14496]

# %%
data_set[0][paradigm_info == OPEN_HAND]
# Out:
# array([ 12.08      ,  12.08083333,  12.08166667, ..., 419.8775    ,
#        419.87833333, 419.87916667])

# %%
# Change in Finger Movement over time
hand_list = [data_set[62], data_set[63], data_set[64], data_set[65], data_set[66]]

for data in hand_list:
    plt.figure(figsize=(22,4 ))
    plt.plot(data)
    plt.show()

# %%
plt.plot(data_set[0], data_set[11])

# %%
relax_time = data_set[0][paradigm_info == RELAX]
relax_sample = data_set[65][paradigm_info == RELAX]

fist_time = data_set[0][paradigm_info == FIST_MOVEMENT]
fist_sample = data_set[65][paradigm_info == FIST_MOVEMENT]

peace_time = data_set[0][paradigm_info == PEACE_MOVEMENT]
peace_sample = data_set[65][paradigm_info == PEACE_MOVEMENT]

open_hand_time = data_set[0][paradigm_info == OPEN_HAND]
open_hand_sample = data_set[65][paradigm_info == OPEN_HAND]

time_list = [relax_time, fist_time, peace_time, open_hand_time]
sample_list = [relax_sample, fist_sample, peace_sample, open_hand_sample]

## 
for time, data in zip(time_list, sample_list):
    plt.figure(figsize=(22,4 ))
    plt.plot(time, data)
    plt.show()

# %%
for data in sample_list:
    plt.figure(figsize=(22,4 ))
    plt.plot(data)
    plt.show()

# %%
relax_time = data_set[0][paradigm_info == RELAX]
relax_sample = data_set[2][paradigm_info == RELAX]
relax_sample[16]
# Out:
# 56676.359375

# %%
data_set[1][16]
# Out:
# 56377.390625
